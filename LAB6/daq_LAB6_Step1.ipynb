# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv


indoor_data = pd.read_csv("LAB6_indoors.csv")
outdoor_data_uncut = pd.read_csv("LAB6_outdoors.csv")
outdoor_data = outdoor_data_uncut[127:]

# %%
#plt.plot(indoor_data["Time"], indoor_data["Temperature"])
plt.plot(outdoor_data["Time"], outdoor_data["PM2.5"])

# %% [markdown]
# ## Histograms

# %%
plt.hist(indoor_data["PM2.5"], alpha = 0.5, bins = [0.5,1.5,2.5,3.5], color = "purple", label = "Indoor Data")
plt.hist(outdoor_data["PM2.5"], bins = [0.5,1.5,2.5,3.5,4.5,5.5,6.5,7.5,8.5], alpha = 0.5, color = "red", label = "Outdoor Data" )
plt.title("PM2.5 Indoors vs Outdoors")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["PM10"], bins = [1.5,2.5,3.5,4.5], alpha = 0.5, color = "purple", label = "Outdoor Data")
plt.hist(outdoor_data["PM10"], bins = [1.5,2.5,3.5,4.5,5.5,6.5,7.5,8.5,9.5,10.5,11.5,12.5], color = "red", alpha = 0.5, label = "Indoor Data")
plt.title("PM10 Indoors vs Outdoors")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["Temperature"], alpha = 0.5, color = "purple", label = "Indoor Data")
plt.hist(outdoor_data["Temperature"], alpha = 0.5, color = "red", label = "Outdoor Data" )
plt.title("Temperature Indoors vs Outdoors")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["Gas"], alpha = 0.5, color = "purple", label = "Indoor Data")
plt.hist(outdoor_data["Gas"], alpha = 0.5, color = "red", label = "Outdoor Data" )
plt.title("Gas Indoors vs Outdoors")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["Humidity"], alpha = 0.5, color = "purple", label = "Indoor Data")
plt.hist(outdoor_data["Humidity"], alpha = 0.5, color = "red", label = "Outdoor Data" )
plt.title("Humidity Indoors vs Outdoors")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["Pressure"], alpha = 0.5, color = "purple", label = "Indoor Data")
plt.hist(outdoor_data["Pressure"], alpha = 0.5, color = "red", label = "Outdoor Data" )
plt.title("Pressure Indoors vs Outdoors")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["Altitude"], alpha = 0.5, color = "purple", label = "Indoor Data")
plt.hist(outdoor_data["Altitude"], alpha = 0.5, color = "red", label = "Outdoor Data" )
plt.title("Altitude Indoors vs Outdoors")
plt.legend()
plt.show()

# %% [markdown]
# Task 3a:
# * The range for the indoor measurements is significantly smaller for most variables than for the outdoor measurements, therefore the boxes in the histograms are also much smaller.

# %%
## sd of pm2.5

sm_PM25_i = np.std(indoor_data["PM2.5"])/np.sqrt(297)
sm_PM25_o = np.std(outdoor_data["PM2.5"])/np.sqrt(297)

meani = np.mean(indoor_data["PM2.5"])
meano = np.mean(outdoor_data["PM2.5"])
stdi = np.std(indoor_data["PM2.5"])
stdo = np.std(outdoor_data["PM2.5"])

print("Indoor Mean: ", meani)
print("Outdoor Mean:", meano)
print("Indoor std.: ", stdi)
print("Outdoor std.:", stdo)

separation25 = (meano-meani)/sm_PM25_i

print(sm_PM25_i)
print("Separation =", separation25, "std. of the mean")
print("They are significantly different")
# Out:
# Indoor Mean:  3.414141414141414
# Outdoor Mean: 7.964705882352941
# Indoor std.:  0.8607815062783739
# Outdoor std.: 0.9067986198843829
# 0.04994760896765138
# Separation = 91.10675290099884 std. of the mean
# They are significantly different

# %%
## sd of pm10
sm_PM10_i = np.std(indoor_data["PM10"])/np.sqrt(297)
sm_PM10_o = np.std(outdoor_data["PM10"])/np.sqrt(297)

meani = np.mean(indoor_data["PM10"])
meano = np.mean(outdoor_data["PM10"])
stdi = np.std(indoor_data["PM10"])
stdo = np.std(outdoor_data["PM10"])

print("Indoor Mean: ", meani)
print("Outdoor Mean:", meano)
print("Indoor std.: ", stdi)
print("Outdoor std.:", stdo)

separation10 = (meano-meani)/sm_PM10_i

print(sm_PM10_i)
print("Separation =", separation10, "std. of the mean")
print("They are significantly different")
# Out:
# Indoor Mean:  3.515151515151515
# Outdoor Mean: 9.429411764705883
# Indoor std.:  0.816871378551749
# Outdoor std.: 1.240618776295477
# 0.047399684931862654
# Separation = 124.77425236172252 std. of the mean
# They are significantly different

# %%
## sd of temp

sm_temp_i = np.std(indoor_data["Temperature"])/np.sqrt(297)
sm_temp_o = np.std(outdoor_data["Temperature"])/np.sqrt(297)

meani = np.mean(indoor_data["Temperature"])
meano = np.mean(outdoor_data["Temperature"])
stdi = np.std(indoor_data["Temperature"])
stdo = np.std(outdoor_data["Temperature"])

print("Indoor Mean: ", meani)
print("Outdoor Mean:", meano)
print("Indoor std.: ", stdi)
print("Outdoor std.:", stdo)

separationtemp = np.abs(meano-meani)/sm_temp_i

print(sm_temp_i)
print("Separation =", separationtemp, "std. of the mean")
print("They are significantly different")
# Out:
# Indoor Mean:  23.95661182133838
# Outdoor Mean: 17.156263786764708
# Indoor std.:  0.11227606035452985
# Outdoor std.: 1.150872647483713
# 0.006514917802152338
# Separation = 1043.8117933471144 std. of the mean
# They are significantly different

# %%
## sd of gas

meani = np.mean(indoor_data["Gas"])
meano = np.mean(outdoor_data["Gas"])

sm_gas_i = np.std(indoor_data["Gas"])/np.sqrt(297)
sm_gas_o = np.std(outdoor_data["Gas"])/np.sqrt(297)

meani = np.mean(indoor_data["Gas"])
meano = np.mean(outdoor_data["Gas"])
stdi = np.std(indoor_data["Gas"])
stdo = np.std(outdoor_data["Gas"])

print("Indoor Mean: ", meani)
print("Outdoor Mean:", meano)
print("Indoor std.: ", stdi)
print("Outdoor std.:", stdo)

separationgas = np.abs(meano-meani)/sm_gas_i

print(sm_gas_i)
print("Separation =", separationgas, "std. of the mean")
print("They are significantly different")
# Out:
# Indoor Mean:  253731.3164983165
# Outdoor Mean: 328292.8294117647
# Indoor std.:  27029.676195243148
# Outdoor std.: 6952.440473782418
# 1568.4208911031508
# Separation = 47.53922453876858 std. of the mean
# They are significantly different

# %%
## sd of humidity

sm_hum_i = np.std(indoor_data["Humidity"])/np.sqrt(297)
sm_hum_o = np.std(outdoor_data["Humidity"])/np.sqrt(297)

meani = np.mean(indoor_data["Humidity"])
meano = np.mean(outdoor_data["Humidity"])
stdi = np.std(indoor_data["Humidity"])
stdo = np.std(outdoor_data["Humidity"])

print("Indoor Mean: ", meani)
print("Outdoor Mean:", meano)
print("Indoor std.: ", stdi)
print("Outdoor std.:", stdo)

separationhum = np.abs(meano-meani)/sm_hum_i

print(sm_hum_i)
print("Separation =", separationhum, "std. of the mean")
print("They are significantly different")
# Out:
# Indoor Mean:  43.17203271870542
# Outdoor Mean: 54.12182357478944
# Indoor std.:  0.609519426117365
# Outdoor std.: 3.876357507158039
# 0.03536790431932435
# Separation = 309.59682420598676 std. of the mean
# They are significantly different

# %%
## sd of pressure

sm_pressure_i = np.std(indoor_data["Pressure"])/np.sqrt(297)
sm_pressure_o = np.std(outdoor_data["Pressure"])/np.sqrt(297)

meani = np.mean(indoor_data["Pressure"])
meano = np.mean(outdoor_data["Pressure"])
stdi = np.std(indoor_data["Pressure"])
stdo = np.std(outdoor_data["Pressure"])

print("Indoor Mean: ", meani)
print("Outdoor Mean:", meano)
print("Indoor std.: ", stdi)
print("Outdoor std.:", stdo)

separationpressure = np.abs(meano-meani)/sm_pressure_i

print(sm_pressure_i)
print("Separation =", separationpressure, "std. of the mean")
print("They are significantly different")
# Out:
# Indoor Mean:  1008.5723408691393
# Outdoor Mean: 1008.2610688358457
# Indoor std.:  0.013942511548918774
# Outdoor std.: 0.4492410381288986
# 0.0008090265761903421
# Separation = 384.7488357668514 std. of the mean
# They are significantly different

# %%
## sd of altitude

sm_alt_i = np.std(indoor_data["Altitude"])/np.sqrt(297)
sm_alt_o = np.std(outdoor_data["Altitude"])/np.sqrt(297)

meani = np.mean(indoor_data["Altitude"])
meano = np.mean(outdoor_data["Altitude"])
stdi = np.std(indoor_data["Altitude"])
stdo = np.std(outdoor_data["Altitude"])

print("Indoor Mean: ", meani)
print("Outdoor Mean:", meano)
print("Indoor std.: ", stdi)
print("Outdoor std.:", stdo)

separationalt = np.abs(meano-meani)/sm_alt_i

print(sm_alt_i)
print("Separation =", separationalt, "std. of the mean")
print("They are significantly different")
# Out:
# Indoor Mean:  39.01770147656692
# Outdoor Mean: 41.61998360355138
# Indoor std.:  0.11651756305194579
# Outdoor std.: 3.7553143958666366
# 0.006761034751250983
# Separation = 384.8940617415059 std. of the mean
# They are significantly different

# %% [markdown]
# Some of the variables clearly show a Gaussian distribution, so the data seems to be sufficient. For some variables like Pressure a non-normal distribution is expected as we moved around.
