# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv


indoor_data = pd.read_csv("LAB6_indoors.csv")
indoor_data_Erick_uncut = pd.read_csv("LAB6_indoors_Erick.csv")
indoor_data_Erick = indoor_data_Erick_uncut[1:]

# %%
#plt.plot(indoor_data["Time"], indoor_data["Temperature"])
plt.plot(indoor_data_Erick["Time"], indoor_data_Erick["Temperature"])

# %% [markdown]
# ## Histograms

# %%
plt.hist(indoor_data["PM2.5"], alpha = 0.5, bins = [0.5,1.5,2.5,3.5], color = "purple", label = "Indoor Data")
plt.hist(indoor_data_Erick["PM2.5"], bins = [0.5,1.5,2.5,3.5,4.5,5.5,6.5,7.5,8.5], alpha = 0.5, color = "red", label = "Indoor Data Erick" )
plt.title("PM2.5 Indoors Ours vs Ericks")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["PM10"], bins = [1.5,2.5,3.5,4.5], alpha = 0.5, color = "purple", label = "Indoor Data Erick")
plt.hist(indoor_data_Erick["PM10"], bins = [1.5,2.5,3.5,4.5,5.5,6.5,7.5,8.5,9.5,10.5,11.5,12.5], color = "red", alpha = 0.5, label = "Indoor Data")
plt.title("PM10 Indoors Ours vs Ericks")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["Temperature"], alpha = 0.5, color = "purple", label = "Indoor Data")
plt.hist(indoor_data_Erick["Temperature"], bins=10, alpha = 0.5, color = "red", label = "Indoor Data Erick" )
plt.title("Temperature Indoors Ours vs Ericks")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["Gas"], alpha = 0.5, color = "purple", label = "Indoor Data")
plt.hist(indoor_data_Erick["Gas"], alpha = 0.5, color = "red", label = "Indoor Data Erick" )
plt.title("Gas Indoors Ours vs Ericks")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["Humidity"], alpha = 0.5, color = "purple", label = "Indoor Data")
plt.hist(indoor_data_Erick["Humidity"], alpha = 0.5, color = "red", label = "Indoor Data Erick" )
plt.title("Humidity Indoors Ours vs Ericks")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["Pressure"], alpha = 0.5, color = "purple", label = "Indoor Data")
plt.hist(indoor_data_Erick["Pressure"], alpha = 0.5, color = "red", label = "Indoor Data Erick" )
plt.title("Pressure Indoors Ours vs Ericks")
plt.legend()
plt.show()

# %%
plt.hist(indoor_data["Altitude"], alpha = 0.5, color = "purple", label = "Indoor Data")
plt.hist(indoor_data_Erick["Altitude"], alpha = 0.5, color = "red", label = "Indoor Data Erick" )
plt.title("Altitude Indoors Ours vs Ericks")
plt.legend()
plt.show()

# %%
## sd of pm2.5

sm_PM25_i = np.std(indoor_data["PM2.5"])/np.sqrt(297)
sm_PM25_o = np.std(indoor_data_Erick["PM2.5"])/np.sqrt(297)

meani = np.mean(indoor_data["PM2.5"])
meano = np.mean(indoor_data_Erick["PM2.5"])
stdi = np.std(indoor_data["PM2.5"])
stdo = np.std(indoor_data_Erick["PM2.5"])

print("Our Mean: ", meani)
print("Erick mean:", meano)
print("Our std.: ", stdi)
print("Erick std.:", stdo)

separation25 = (meano-meani)/sm_PM25_i

print( )
print("Separation =", separation25, "std. of the mean")
print("They are significantly different")
# Out:
# Our Mean:  3.414141414141414
# Erick mean: 4.162162162162162
# Our std.:  0.8607815062783739
# Erick std.: 0.9554541445574913
#
# Separation = 14.97610723478685 std. of the mean
# They are significantly different

# %%
## sd of pm10
sm_PM10_i = np.std(indoor_data["PM10"])/np.sqrt(297)
sm_PM10_o = np.std(indoor_data_Erick["PM10"])/np.sqrt(297)

meani = np.mean(indoor_data["PM10"])
meano = np.mean(indoor_data_Erick["PM10"])
stdi = np.std(indoor_data["PM10"])
stdo = np.std(indoor_data_Erick["PM10"])

print("Our Mean: ", meani)
print("Erick mean:", meano)
print("Our std.: ", stdi)
print("Erick std.:", stdo)

separation10 = (meano-meani)/sm_PM10_i

print( )
print("Separation =", separation10, "std. of the mean")
print("They are significantly different")
# Out:
# Our Mean:  3.515151515151515
# Erick mean: 4.618243243243243
# Our std.:  0.816871378551749
# Erick std.: 1.182446911108266
#
# Separation = 23.27213207592897 std. of the mean
# They are significantly different

# %%
## sd of temp

sm_temp_i = np.std(indoor_data["Temperature"])/np.sqrt(297)
sm_temp_o = np.std(indoor_data_Erick["Temperature"])/np.sqrt(297)

meani = np.mean(indoor_data["Temperature"])
meano = np.mean(indoor_data_Erick["Temperature"])
stdi = np.std(indoor_data["Temperature"])
stdo = np.std(indoor_data_Erick["Temperature"])

print("Our Mean: ", meani)
print("Erick mean:", meano)
print("Our std.: ", stdi)
print("Erick std.:", stdo)

separationtemp = np.abs(meano-meani)/sm_temp_i

print( )
print("Separation =", separationtemp, "std. of the mean")
print("They are significantly different")
# Out:
# Our Mean:  23.95661182133838
# Erick mean: 24.108866000810814
# Our std.:  0.11227606035452985
# Erick std.: 0.07294714993246791
#
# Separation = 23.370084488576705 std. of the mean
# They are significantly different

# %%
## sd of gas

meani = np.mean(indoor_data["Gas"])
meano = np.mean(indoor_data_Erick["Gas"])

sm_gas_i = np.std(indoor_data["Gas"])/np.sqrt(297)
sm_gas_o = np.std(indoor_data_Erick["Gas"])/np.sqrt(297)

meani = np.mean(indoor_data["Gas"])
meano = np.mean(indoor_data_Erick["Gas"])
stdi = np.std(indoor_data["Gas"])
stdo = np.std(indoor_data_Erick["Gas"])

print("Our Mean: ", meani)
print("Erick mean:", meano)
print("Our std.: ", stdi)
print("Erick std.:", stdo)

separationgas = np.abs(meano-meani)/sm_gas_i

print( )
print("Separation =", separationgas, "std. of the mean")
print("They are significantly different")
# Out:
# Our Mean:  253731.3164983165
# Erick mean: 219443.7939189189
# Our std.:  27029.676195243148
# Erick std.: 45678.59538085277
#
# Separation = 21.861174365817984 std. of the mean
# They are significantly different

# %%
## sd of humidity

sm_hum_i = np.std(indoor_data["Humidity"])/np.sqrt(297)
sm_hum_o = np.std(indoor_data_Erick["Humidity"])/np.sqrt(297)

meani = np.mean(indoor_data["Humidity"])
meano = np.mean(indoor_data_Erick["Humidity"])
stdi = np.std(indoor_data["Humidity"])
stdo = np.std(indoor_data_Erick["Humidity"])

print("Our Mean: ", meani)
print("Erick mean:", meano)
print("Our std.: ", stdi)
print("Erick std.:", stdo)

separationhum = np.abs(meano-meani)/sm_hum_i

print( )
print("Separation =", separationhum, "std. of the mean")
print("They are significantly different")
# Out:
# Our Mean:  43.17203271870542
# Erick mean: 40.512238446858106
# Our std.:  0.609519426117365
# Erick std.: 0.2790474030563612
#
# Separation = 75.20361534098727 std. of the mean
# They are significantly different

# %%
## sd of pressure

sm_pressure_i = np.std(indoor_data["Pressure"])/np.sqrt(297)
sm_pressure_o = np.std(indoor_data_Erick["Pressure"])/np.sqrt(297)

meani = np.mean(indoor_data["Pressure"])
meano = np.mean(indoor_data_Erick["Pressure"])
stdi = np.std(indoor_data["Pressure"])
stdo = np.std(indoor_data_Erick["Pressure"])

print("Our Mean: ", meani)
print("Erick mean:", meano)
print("Our std.: ", stdi)
print("Erick std.:", stdo)

separationpressure = np.abs(meano-meani)/sm_pressure_i

print( )
print("Separation =", separationpressure, "std. of the mean")
print("They are significantly different")
# Out:
# Our Mean:  1008.5723408691393
# Erick mean: 1008.6473232702704
# Our std.:  0.013942511548918774
# Erick std.: 0.03270452375624821
#
# Separation = 92.68224720640389 std. of the mean
# They are significantly different

# %%
## sd of altitude

sm_alt_i = np.std(indoor_data["Altitude"])/np.sqrt(297)
sm_alt_o = np.std(indoor_data_Erick["Altitude"])/np.sqrt(297)

meani = np.mean(indoor_data["Altitude"])
meano = np.mean(indoor_data_Erick["Altitude"])
stdi = np.std(indoor_data["Altitude"])
stdo = np.std(indoor_data_Erick["Altitude"])

print("Our Mean: ", meani)
print("Erick mean:", meano)
print("Our std.: ", stdi)
print("Erick std.:", stdo)

separationalt = np.abs(meano-meani)/sm_alt_i

print( )
print("Separation =", separationalt, "std. of the mean")
print("They are significantly different")
# Out:
# Our Mean:  39.01770147656692
# Erick mean: 38.39110034679054
# Our std.:  0.11651756305194579
# Erick std.: 0.273292285536335
#
# Separation = 92.67828858007918 std. of the mean
# They are significantly different

# %% [markdown]
# Some of the variables clearly show a Gaussian distribution, so the data seems to be sufficient. For some variables like Pressure a non-normal distribution is expected as we moved around.
