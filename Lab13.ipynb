# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

uncut_indoor = pd.read_csv("Loc1_session1_group1_2024-04-12_16-36-17.csv")

uncut_outdoor = pd.read_csv("Loc2_session1_group1_2024-04-12_16-45-33.csv")

indoor_data = uncut_indoor[2:]
outdoor_data = uncut_outdoor[2:]

# %%
display(indoor_data)

display(outdoor_data)
# Out:
#              Time  Latitude  Longitude  counts  Temperature   Humidity  \
# 2    1.712965e+09         0          0    42.5    25.262715  35.149541
# 3    1.712965e+09         0          0    42.5    25.337812  34.881438
# 4    1.712965e+09         0          0    46.0    25.390547  34.657865
# 5    1.712965e+09         0          0    45.5    25.429512  34.447713
# 6    1.712965e+09         0          0    37.5    25.458711  34.297488
# ..            ...       ...        ...     ...          ...        ...
# 148  1.712965e+09         0          0    40.0    25.736738  33.836798
# 149  1.712965e+09         0          0    37.5    25.742500  33.837342
# 150  1.712965e+09         0          0    34.0    25.742695  33.820092
# 151  1.712965e+09         0          0    46.5    25.741523  33.817104
# 152  1.712965e+09         0          0    46.5    25.735371  33.793505
#
#        Pressure    Altitude       VOC
# 2    997.957341  128.106972   71900.0
# ...

# %% [markdown]
# ## a
# We have no AQ data.

# %%
plt.plot(indoor_data["counts"], color = "purple", label = "Indoor")
plt.plot(outdoor_data["counts"], label = "Outdoor")
plt.xlabel("Time")
plt.ylabel("Counts")
plt.legend()
plt.title("Counts Outdoors and Indoors")
plt.show()

# %%
plt.plot(indoor_data["Temperature"], color = "purple", label = "Indoor")
plt.plot(outdoor_data["Temperature"], label = "Outdoor")
plt.xlabel("Time")
plt.ylabel("Temperature (C)")
plt.legend()
plt.title("Temperature Outdoors and Indoors")
plt.show()

# %% [markdown]
# ## b

# %%
# counts

plt.hist(indoor_data["counts"], alpha = 0.5, color = "purple", label = "Indoor")
plt.hist(outdoor_data["counts"],alpha = 0.5, label = "Outdoor")
plt.xlabel("Counts")
plt.ylabel("Frequency")
plt.legend()
plt.title("Counts Outdoors and Indoors")
plt.show()


indoor_mean = np.mean(indoor_data["counts"])
outdoor_mean = np.mean(outdoor_data["counts"])

indoor_std_counts = np.std(indoor_data["counts"])
outdoor_std_counts = np.std(outdoor_data["counts"])

d = {'': ["mean","std"], 'Indoor': [indoor_mean,indoor_std_counts], 'Outdoor':[outdoor_mean,outdoor_std_counts] }

df = pd.DataFrame(data = d)

display(df)
# Out:
#             Indoor    Outdoor
# 0  mean  41.089404  35.832237
# 1   std   4.680906   4.436298

# %%
# Temperature

plt.hist(indoor_data["Temperature"], alpha = 0.5, color = "purple")
plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.title("Temperature Indoors")
plt.show()


plt.hist(outdoor_data["Temperature"],alpha = 0.5)
plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.title("Temperature Outdoors")
plt.show()


indoor_mean = np.mean(indoor_data["Temperature"])
outdoor_mean = np.mean(outdoor_data["Temperature"])

indoor_std = np.std(indoor_data["Temperature"])
outdoor_std = np.std(outdoor_data["Temperature"])

d = {'': ["mean","std"], 'Indoor': [indoor_mean,indoor_std], 'Outdoor':[outdoor_mean,outdoor_std] }

df = pd.DataFrame(data = d)

display(df)
# Out:
#             Indoor    Outdoor
# 0  mean  25.633684  17.867900
# 1   std   0.098696   0.563427

# %%
# Humidity

plt.hist(indoor_data["Humidity"], alpha = 0.5, color = "purple")
plt.xlabel("Humidity")
plt.ylabel("Frequency")
plt.title("Humidity Indoors")
plt.show()


plt.hist(outdoor_data["Humidity"],alpha = 0.5)
plt.xlabel("Humidity")
plt.ylabel("Frequency")
plt.title("Humidity Outdoors")
plt.show()


indoor_mean = np.mean(indoor_data["Humidity"])
outdoor_mean = np.mean(outdoor_data["Humidity"])

indoor_std = np.std(indoor_data["Humidity"])
outdoor_std = np.std(outdoor_data["Humidity"])

d = {'': ["mean","std"], 'Indoor': [indoor_mean,indoor_std], 'Outdoor':[outdoor_mean,outdoor_std] }

df = pd.DataFrame(data = d)

display(df)
# Out:
#             Indoor    Outdoor
# 0  mean  34.182732  44.931735
# 1   std   0.727672   1.248348

# %%
# Pressure

plt.hist(indoor_data["Pressure"], alpha = 0.5, color = "purple")
plt.xlabel("Pressure")
plt.ylabel("Frequency")
plt.title("Pressure Indoors")
plt.show()


plt.hist(outdoor_data["Pressure"],alpha = 0.5)
plt.xlabel("Pressure")
plt.ylabel("Frequency")
plt.title("Pressure Outdoors")
plt.show()


indoor_mean = np.mean(indoor_data["Pressure"])
outdoor_mean = np.mean(outdoor_data["Pressure"])

indoor_std = np.std(indoor_data["Pressure"])
outdoor_std = np.std(outdoor_data["Pressure"])

d = {'': ["mean","std"], 'Indoor': [indoor_mean,indoor_std], 'Outdoor':[outdoor_mean,outdoor_std] }

df = pd.DataFrame(data = d)

display(df)
# Out:
#              Indoor     Outdoor
# 0  mean  997.943004  996.808290
# 1   std    0.032648    0.023174

# %%
# Altitude

plt.hist(indoor_data["Altitude"], alpha = 0.5, color = "purple")
plt.xlabel("Altitude")
plt.ylabel("Frequency")
plt.title("Altitude Indoors")
plt.show()


plt.hist(outdoor_data["Altitude"],alpha = 0.5)
plt.xlabel("Altitude")
plt.ylabel("Frequency")
plt.title("Altitude Outdoors")
plt.show()


indoor_mean = np.mean(indoor_data["Altitude"])
outdoor_mean = np.mean(outdoor_data["Altitude"])

indoor_std = np.std(indoor_data["Altitude"])
outdoor_std = np.std(outdoor_data["Altitude"])

d = {'': ["mean","std"], 'Indoor': [indoor_mean,indoor_std], 'Outdoor':[outdoor_mean,outdoor_std] }

df = pd.DataFrame(data = d)

display(df)
# Out:
#              Indoor     Outdoor
# 0  mean  128.227819  137.796655
# 1   std    0.275195    0.195512

# %%
# VOC

plt.hist(indoor_data["VOC"], alpha = 0.5, color = "purple")
plt.xlabel("VOC")
plt.ylabel("Frequency")
plt.title("VOC Indoors")
plt.show()


plt.hist(outdoor_data["VOC"],alpha = 0.5)
plt.xlabel("VOC")
plt.ylabel("Frequency")
plt.title("VOC Outdoors")
plt.show()


indoor_mean = np.mean(indoor_data["VOC"])
outdoor_mean = np.mean(outdoor_data["VOC"])

indoor_std = np.std(indoor_data["VOC"])
outdoor_std = np.std(outdoor_data["VOC"])

d = {'': ["mean","std"], 'Indoor': [indoor_mean,indoor_std], 'Outdoor':[outdoor_mean,outdoor_std] }

df = pd.DataFrame(data = d)

display(df)


plt.hist(indoor_data["VOC"], alpha = 0.5, color = "purple")
plt.hist(outdoor_data["VOC"],alpha = 0.5)
plt.show()
# Out:
#                 Indoor        Outdoor
# 0  mean  100981.294702  107210.845395
# 1   std    5455.450052   10981.966313

# %% [markdown]
# # b i

# %% [markdown]
# ## c

# %%
counts_inside = np.mean(indoor_data["counts"])

counts_outside = np.mean(outdoor_data["counts"]) 

var_inside = np.sqrt(counts_inside)

var_outside = np.sqrt(counts_outside)

print(var_inside,var_outside)
# Out:
# 6.410101713195347 5.986003411467894

# %% [markdown]
# Inside and outside both had a standard deviation of about 4.

# %% [markdown]
# ## d

# %%
samples_inside = np.sqrt(151)
samples_outside = np.sqrt(152)

sigma_inside = var_inside/np.sqrt(2*samples_inside)

sigma_outside = var_outside/np.sqrt(2*samples_outside)

print(sigma_inside,sigma_outside)
# Out:
# 1.2930213210041859 1.2054829304909696

# %% [markdown]
# ## e

# %%
comp_inside=(var_inside-indoor_std_counts)/sigma_inside
comp_outside=(var_outside-outdoor_std_counts)/sigma_outside
print(comp_inside, comp_outside)
# Out:
# 1.3373296110395552 1.285547636300375

# %% [markdown]
# ## f

# %%
difference = (counts_inside-counts_outside)/((var_inside+var_outside)/2)
print(difference)
# Out:
# 0.8481966034549082
